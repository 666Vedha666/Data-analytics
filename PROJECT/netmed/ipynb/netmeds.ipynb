# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the WebDriver with headless option
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run browser in headless mode
options.add_argument('--no-sandbox')  # Recommended option for headless mode
options.add_argument('--disable-dev-shm-usage')  # Disable shared memory usage for better stability

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Start with the first page
base_url = 'https://www.netmeds.com/catalogsearch/result/vitamin%20c/all?prod_meds%5Bpage%5D=4'
driver.get(base_url)

# Initialize an empty list to store product data
product_data = []
max_products = 100  # Set limit to stop after collecting a certain number of products

def extract_product_details():
    products = driver.find_elements(By.CSS_SELECTOR, 'div.cat-item ')

    for product in products:
        if len(product_data) >= max_products:  # Stop if we have enough data
            return False

        product_info = {}

        try:
            # Extract title
            title_elements = product.find_elements(By.CSS_SELECTOR, 'h3.clsgetname')
            title = title_elements[0].text if title_elements else 'No title'
            product_info['title'] = title
            print(f"Title: {title}")

            # Extract price
            price_elements = product.find_elements(By.CSS_SELECTOR, 'span.final-price')
            price = price_elements[0].text if price_elements else 'No price'
            product_info['price'] = price
            print(f"Price: {price}")

            # Append the product info to the list
            product_data.append(product_info)

            # Print product information to show the scraping progress
            print(f"Scraped product {len(product_data)}: {product_info}")

        except Exception as e:
            print(f"Error while scraping product: {e}")
            continue

    return True  # Continue scraping

# Scroll the page and extract products until we reach the max product limit
scroll_pause_time = 2  # Adjust if needed for smoother scrolling
while len(product_data) < max_products:
    extract_success = extract_product_details()

    if not extract_success:
        break

    # Scroll down to load more products
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Wait for the page to load new products
    time.sleep(scroll_pause_time)

# Close the driver after scraping
driver.quit()

# Convert the product data into a DataFrame and save it to an Excel file
df = pd.DataFrame(product_data)
df.to_excel('netmeds_c.xlsx', index=False)  # Use .to_excel() for Excel format
print('Data saved to netmeds_c.xlsx.')
# Out:
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's
# Price: ₹1007.37
# Scraped product 1: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's", 'price': '₹1007.37'}
# Title: Vitaminhaat Vitamin-C Capsule 90's
# Price: ₹818.37
# Scraped product 2: {'title': "Vitaminhaat Vitamin-C Capsule 90's", 'price': '₹818.37'}
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's
# Price: ₹1007.37
# Scraped product 3: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's", 'price': '₹1007.37'}
# Title: Zenius Vitamin C Lemon Gummies 30's
# Price: ₹549.45
# Scraped product 4: {'title': "Zenius Vitamin C Lemon Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Orange Gummies 30's
# Price: ₹549.45
# Scraped product 5: {'title': "Zenius Vitamin C Orange Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Lychee Gummies 30's
# Price: ₹549.45
# Scraped product 6: {'title': "Zenius Vitamin C Lychee Gummies 30's", 'price': '₹549.45'}
# Title: Inlife Vitamin C Gummies - Orange Flavour 30's
# Price: ₹338.82
# Scraped product 7: {'title': "Inlife Vitamin C Gummies - Orange Flavour 30's", 'price': '₹338.82'}
# Title: Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C
# Price: ₹327.18
# Scraped product 8: {'title': 'Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C', 'price': '₹327.18'}
# Title: Vitaminhaat Amalaki Vitamin-C Capsule 90's
# Price: ₹629.37
# Scraped product 9: {'title': "Vitaminhaat Amalaki Vitamin-C Capsule 90's", 'price': '₹629.37'}
# Title: Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's
# Price: ₹385.15
# Scraped product 10: {'title': "Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's", 'price': '₹385.15'}
# Title: Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's
# Price: ₹380.96
# Scraped product 11: {'title': "Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's", 'price': '₹380.96'}
# Title: Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's
# Price: ₹215.64
# Scraped product 12: {'title': "Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's", 'price': '₹215.64'}
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's
# Price: ₹1007.37
# Scraped product 13: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's", 'price': '₹1007.37'}
# Title: Vitaminhaat Vitamin-C Capsule 90's
# Price: ₹818.37
# Scraped product 14: {'title': "Vitaminhaat Vitamin-C Capsule 90's", 'price': '₹818.37'}
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's
# Price: ₹1007.37
# Scraped product 15: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's", 'price': '₹1007.37'}
# Title: Zenius Vitamin C Lemon Gummies 30's
# Price: ₹549.45
# Scraped product 16: {'title': "Zenius Vitamin C Lemon Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Orange Gummies 30's
# Price: ₹549.45
# Scraped product 17: {'title': "Zenius Vitamin C Orange Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Lychee Gummies 30's
# Price: ₹549.45
# Scraped product 18: {'title': "Zenius Vitamin C Lychee Gummies 30's", 'price': '₹549.45'}
# Title: Inlife Vitamin C Gummies - Orange Flavour 30's
# Price: ₹338.82
# Scraped product 19: {'title': "Inlife Vitamin C Gummies - Orange Flavour 30's", 'price': '₹338.82'}
# Title: Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C
# Price: ₹327.18
# Scraped product 20: {'title': 'Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C', 'price': '₹327.18'}
# Title: Vitaminhaat Amalaki Vitamin-C Capsule 90's
# Price: ₹629.37
# Scraped product 21: {'title': "Vitaminhaat Amalaki Vitamin-C Capsule 90's", 'price': '₹629.37'}
# Title: Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's
# Price: ₹385.15
# Scraped product 22: {'title': "Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's", 'price': '₹385.15'}
# Title: Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's
# Price: ₹380.96
# Scraped product 23: {'title': "Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's", 'price': '₹380.96'}
# Title: Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's
# Price: ₹215.64
# Scraped product 24: {'title': "Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's", 'price': '₹215.64'}
# Title: Chicnutrix Glow - Glutathione & Vitamin C For Skin Radiance - Strawberry & Lemon Flavour 20 Tablets 1's
# Price: ₹1405.80
# Scraped product 25: {'title': "Chicnutrix Glow - Glutathione & Vitamin C For Skin Radiance - Strawberry & Lemon Flavour 20 Tablets 1's", 'price': '₹1405.80'}
# Title: Briyo Elderberry Plus Vitamin C - Chewable Tablets - Natural Berry Flavour 90's
# Price: ₹374.53
# Scraped product 26: {'title': "Briyo Elderberry Plus Vitamin C - Chewable Tablets - Natural Berry Flavour 90's", 'price': '₹374.53'}
# Title: Neuherbs Hair- Skin Vitamins Capsules 60's
# Price: ₹799.20
# Scraped product 27: {'title': "Neuherbs Hair- Skin Vitamins Capsules 60's", 'price': '₹799.20'}
# Title: Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Tablets - Fizzy Blast Orange Flavour 20's
# Price: ₹340.00
# Scraped product 28: {'title': "Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Tablets - Fizzy Blast Orange Flavour 20's", 'price': '₹340.00'}
# Title: Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Effervesent Tablet - Fizzy Blast Orange Flavour (Pack of 3 x 20's)
# Price: ₹943.50
# Scraped product 29: {'title': "Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Effervesent Tablet - Fizzy Blast Orange Flavour (Pack of 3 x 20's)", 'price': '₹943.50'}
# Title: Asterveda Livon Lypho Spheric Vitamin C Liquid (Pack of 30 x 5.7 ml)
# Price: ₹4019.33
# Scraped product 30: {'title': 'Asterveda Livon Lypho Spheric Vitamin C Liquid (Pack of 30 x 5.7 ml)', 'price': '₹4019.33'}
# Title: NutritJet Super B-Complex with Vitamin C Tablets 120's
# Price: No price
# Scraped product 31: {'title': "NutritJet Super B-Complex with Vitamin C Tablets 120's", 'price': 'No price'}
# Title: LifeZen Tuskca Natural Immunity Booster Vitamin C 1000 mg Tablet - Orange 20's
# Price: ₹348.75
# Scraped product 32: {'title': "LifeZen Tuskca Natural Immunity Booster Vitamin C 1000 mg Tablet - Orange 20's", 'price': '₹348.75'}
# Title: Pure Nutrition Glutathione 500 mg with Vitamin C & Saffron Effervescent Tablet - Orange 15's
# Price: ₹349.65
# Scraped product 33: {'title': "Pure Nutrition Glutathione 500 mg with Vitamin C & Saffron Effervescent Tablet - Orange 15's", 'price': '₹349.65'}
# Title: Wellbeing Nutrition Marvel Thor Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)
# Price: ₹503.28
# Scraped product 34: {'title': 'Wellbeing Nutrition Marvel Thor Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Frozen Olaf Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)
# Price: ₹503.28
# Scraped product 35: {'title': 'Wellbeing Nutrition Frozen Olaf Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Marvel Black Panther Melts Kids Advanced Immunity with Clinically Proven Vitamin C Zinc and D3 - 30 Strips
# Price: ₹503.28
# Scraped product 36: {'title': 'Wellbeing Nutrition Marvel Black Panther Melts Kids Advanced Immunity with Clinically Proven Vitamin C Zinc and D3 - 30 Strips', 'price': '₹503.28'}
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's
# Price: ₹1007.37
# Scraped product 37: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 90's", 'price': '₹1007.37'}
# Title: Vitaminhaat Vitamin-C Capsule 90's
# Price: ₹818.37
# Scraped product 38: {'title': "Vitaminhaat Vitamin-C Capsule 90's", 'price': '₹818.37'}
# Title: Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's
# Price: ₹1007.37
# Scraped product 39: {'title': "Vitaminhaat Vitamin-C with Bioflavonoids & Rosehip Capsule 60's", 'price': '₹1007.37'}
# Title: Zenius Vitamin C Lemon Gummies 30's
# Price: ₹549.45
# Scraped product 40: {'title': "Zenius Vitamin C Lemon Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Orange Gummies 30's
# Price: ₹549.45
# Scraped product 41: {'title': "Zenius Vitamin C Orange Gummies 30's", 'price': '₹549.45'}
# Title: Zenius Vitamin C Lychee Gummies 30's
# Price: ₹549.45
# Scraped product 42: {'title': "Zenius Vitamin C Lychee Gummies 30's", 'price': '₹549.45'}
# Title: Inlife Vitamin C Gummies - Orange Flavour 30's
# Price: ₹338.82
# Scraped product 43: {'title': "Inlife Vitamin C Gummies - Orange Flavour 30's", 'price': '₹338.82'}
# Title: Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C
# Price: ₹327.18
# Scraped product 44: {'title': 'Wellbeing Nutrition Vitamin C + Zinc, Natural and Organic Immunity Booster, 100% RDA 1000mg Vitamin C', 'price': '₹327.18'}
# Title: Vitaminhaat Amalaki Vitamin-C Capsule 90's
# Price: ₹629.37
# Scraped product 45: {'title': "Vitaminhaat Amalaki Vitamin-C Capsule 90's", 'price': '₹629.37'}
# Title: Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's
# Price: ₹385.15
# Scraped product 46: {'title': "Inlife Natural Vitamin C + Zinc 1000 mg Tablet - Orange Flavour 60's", 'price': '₹385.15'}
# Title: Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's
# Price: ₹380.96
# Scraped product 47: {'title': "Inlife Natural Vitamin C Amlaki Ghan 1000 mg Veg Capsule 60's", 'price': '₹380.96'}
# Title: Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's
# Price: ₹215.64
# Scraped product 48: {'title': "Pure Nutrition Vitamin C With Orange Peel & Amla Extract 60's", 'price': '₹215.64'}
# Title: Chicnutrix Glow - Glutathione & Vitamin C For Skin Radiance - Strawberry & Lemon Flavour 20 Tablets 1's
# Price: ₹1405.80
# Scraped product 49: {'title': "Chicnutrix Glow - Glutathione & Vitamin C For Skin Radiance - Strawberry & Lemon Flavour 20 Tablets 1's", 'price': '₹1405.80'}
# Title: Briyo Elderberry Plus Vitamin C - Chewable Tablets - Natural Berry Flavour 90's
# Price: ₹374.53
# Scraped product 50: {'title': "Briyo Elderberry Plus Vitamin C - Chewable Tablets - Natural Berry Flavour 90's", 'price': '₹374.53'}
# Title: Neuherbs Hair- Skin Vitamins Capsules 60's
# Price: ₹799.20
# Scraped product 51: {'title': "Neuherbs Hair- Skin Vitamins Capsules 60's", 'price': '₹799.20'}
# Title: Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Tablets - Fizzy Blast Orange Flavour 20's
# Price: ₹340.00
# Scraped product 52: {'title': "Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Tablets - Fizzy Blast Orange Flavour 20's", 'price': '₹340.00'}
# Title: Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Effervesent Tablet - Fizzy Blast Orange Flavour (Pack of 3 x 20's)
# Price: ₹943.50
# Scraped product 53: {'title': "Fast&Up Charge Natural Vitamin C From Amla Extract & Zinc Effervesent Tablet - Fizzy Blast Orange Flavour (Pack of 3 x 20's)", 'price': '₹943.50'}
# Title: Asterveda Livon Lypho Spheric Vitamin C Liquid (Pack of 30 x 5.7 ml)
# Price: ₹4019.33
# Scraped product 54: {'title': 'Asterveda Livon Lypho Spheric Vitamin C Liquid (Pack of 30 x 5.7 ml)', 'price': '₹4019.33'}
# Title: NutritJet Super B-Complex with Vitamin C Tablets 120's
# Price: No price
# Scraped product 55: {'title': "NutritJet Super B-Complex with Vitamin C Tablets 120's", 'price': 'No price'}
# Title: LifeZen Tuskca Natural Immunity Booster Vitamin C 1000 mg Tablet - Orange 20's
# Price: ₹348.75
# Scraped product 56: {'title': "LifeZen Tuskca Natural Immunity Booster Vitamin C 1000 mg Tablet - Orange 20's", 'price': '₹348.75'}
# Title: Pure Nutrition Glutathione 500 mg with Vitamin C & Saffron Effervescent Tablet - Orange 15's
# Price: ₹349.65
# Scraped product 57: {'title': "Pure Nutrition Glutathione 500 mg with Vitamin C & Saffron Effervescent Tablet - Orange 15's", 'price': '₹349.65'}
# Title: Wellbeing Nutrition Marvel Thor Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)
# Price: ₹503.28
# Scraped product 58: {'title': 'Wellbeing Nutrition Marvel Thor Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Frozen Olaf Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)
# Price: ₹503.28
# Scraped product 59: {'title': 'Wellbeing Nutrition Frozen Olaf Melts Kids Organic Active Probiotic and Prebiotic Vitamin C and D3 (30 Strips)', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Marvel Black Panther Melts Kids Advanced Immunity with Clinically Proven Vitamin C Zinc and D3 - 30 Strips
# Price: ₹503.28
# Scraped product 60: {'title': 'Wellbeing Nutrition Marvel Black Panther Melts Kids Advanced Immunity with Clinically Proven Vitamin C Zinc and D3 - 30 Strips', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Melts Vital Iron Plant Based Iron (ABFortis), Beetroot, Swiss Chard, Pumpkin Seeds, Vitamin C and Folate (30 Strips)
# Price: ₹657.06
# Scraped product 61: {'title': 'Wellbeing Nutrition Melts Vital Iron Plant Based Iron (ABFortis), Beetroot, Swiss Chard, Pumpkin Seeds, Vitamin C and Folate (30 Strips)', 'price': '₹657.06'}
# Title: INLIFE Calcium Vitamin D3 Tablets 60's
# Price: ₹339.89
# Scraped product 62: {'title': "INLIFE Calcium Vitamin D3 Tablets 60's", 'price': '₹339.89'}
# Title: Vitawin Vitamin D Capsules 60's
# Price: ₹664.05
# Scraped product 63: {'title': "Vitawin Vitamin D Capsules 60's", 'price': '₹664.05'}
# Title: Vitawin Vitamin A Capsules 60's
# Price: ₹854.05
# Scraped product 64: {'title': "Vitawin Vitamin A Capsules 60's", 'price': '₹854.05'}
# Title: Miduty Vitamin ADK Capsule 30's
# Price: No price
# Scraped product 65: {'title': "Miduty Vitamin ADK Capsule 30's", 'price': 'No price'}
# Title: Swisse Ultiboost Calcium + Vitamin D Tablet 90's
# Price: ₹1119.20
# Scraped product 66: {'title': "Swisse Ultiboost Calcium + Vitamin D Tablet 90's", 'price': '₹1119.20'}
# Title: INLIFE Glucosamine MSM Calcium Vitamin D3 Tablets 60's
# Price: ₹480.60
# Scraped product 67: {'title': "INLIFE Glucosamine MSM Calcium Vitamin D3 Tablets 60's", 'price': '₹480.60'}
# Title: Swisse Ultiboost Vegan Calcium + Vitamin-D Tablet 60's
# Price: ₹1039.20
# Scraped product 68: {'title': "Swisse Ultiboost Vegan Calcium + Vitamin-D Tablet 60's", 'price': '₹1039.20'}
# Title: Swisse Health Essential (Calcium+ Vitamin D Tablet 90's, Iron Tablet 30's, Wild Fish Oil Capsule 200's) Combo Pack
# Price: ₹3757.60
# Scraped product 69: {'title': "Swisse Health Essential (Calcium+ Vitamin D Tablet 90's, Iron Tablet 30's, Wild Fish Oil Capsule 200's) Combo Pack", 'price': '₹3757.60'}
# Title: Wellbeing Nutrition Melts Eye Care Vitamins with Lute-gen (Lutein + Zeaxanthin), Bilberry, Beetroot (30 Strips)
# Price: ₹597.08
# Scraped product 70: {'title': 'Wellbeing Nutrition Melts Eye Care Vitamins with Lute-gen (Lutein + Zeaxanthin), Bilberry, Beetroot (30 Strips)', 'price': '₹597.08'}
# Title: Ostocalcium B12 Syrup - Lemon Lime Flavour 200 ml
# Price: ₹147.83
# Scraped product 71: {'title': 'Ostocalcium B12 Syrup - Lemon Lime Flavour 200 ml', 'price': '₹147.83'}
# Title: NUTRIBEARS CALCIUM WITH VITAMIN D GUMMY BEARS
# Price: ₹356.00
# Scraped product 72: {'title': 'NUTRIBEARS CALCIUM WITH VITAMIN D GUMMY BEARS', 'price': '₹356.00'}
# Title: Inlife Vitamin D3 60000IU Chewable Tablets 40's
# Price: ₹340.38
# Scraped product 73: {'title': "Inlife Vitamin D3 60000IU Chewable Tablets 40's", 'price': '₹340.38'}
# Title: Inlife Calcium, Zinc, Magnesium, Vitamin D2 + K2 Tablet 120's
# Price: ₹631.10
# Scraped product 74: {'title': "Inlife Calcium, Zinc, Magnesium, Vitamin D2 + K2 Tablet 120's", 'price': '₹631.10'}
# Title: Himalayan Organics Plant Based Vitamin B12 Veg Capsules 60's
# Price: ₹332.26
# Scraped product 75: {'title': "Himalayan Organics Plant Based Vitamin B12 Veg Capsules 60's", 'price': '₹332.26'}
# Title: SheNeed Hair, Skin & Nails Vitamin with Biotin + Collagen Tablet 60's
# Price: ₹475.00
# Scraped product 76: {'title': "SheNeed Hair, Skin & Nails Vitamin with Biotin + Collagen Tablet 60's", 'price': '₹475.00'}
# Title: Wellbeing Nutrition Marvel Captain America Melts Kids Organic Multivitamin with Vitamin A B-Complex C D -30 Strips
# Price: ₹503.28
# Scraped product 77: {'title': 'Wellbeing Nutrition Marvel Captain America Melts Kids Organic Multivitamin with Vitamin A B-Complex C D -30 Strips', 'price': '₹503.28'}
# Title: Wellbeing Nutrition Frozen Elsa and Anna Melts Kids Organic Multivitamin with Vitamin A B-Complex C D (30 Strips)
# Price: ₹503.28
# Scraped product 78: {'title': 'Wellbeing Nutrition Frozen Elsa and Anna Melts Kids Organic Multivitamin with Vitamin A B-Complex C D (30 Strips)', 'price': '₹503.28'}
# Title: Yourhappylife Skin Capsules with Activated L Glutathione, Niacinamide and Retinol Dual Action Capsules with Vitamin E and C for Youthful & Glowing Skin, 30 Capsules 1's
# Price: ₹1104.15
# Scraped product 79: {'title': "Yourhappylife Skin Capsules with Activated L Glutathione, Niacinamide and Retinol Dual Action Capsules with Vitamin E and C for Youthful & Glowing Skin, 30 Capsules 1's", 'price': '₹1104.15'}
# Title: Chicnutrix Super C- Amla Extract and Zinc Effervescent Tablet - Orange Flavour (Pack of 3 x 20's)
# Price: ₹1111.50
# Scraped product 80: {'title': "Chicnutrix Super C- Amla Extract and Zinc Effervescent Tablet - Orange Flavour (Pack of 3 x 20's)", 'price': '₹1111.50'}
# Title: HealthVit Zinc Sulphate 50 mg Tablets 60's
# Price: ₹516.00
# Scraped product 81: {'title': "HealthVit Zinc Sulphate 50 mg Tablets 60's", 'price': '₹516.00'}
# Title: HealthVit Potassium Citrate 99 mg Capsules 60's
# Price: ₹430.00
# Scraped product 82: {'title': "HealthVit Potassium Citrate 99 mg Capsules 60's", 'price': '₹430.00'}
# Title: HealthVit Potassium Iodide 30 mg Tablet 60's
# Price: ₹516.00
# Scraped product 83: {'title': "HealthVit Potassium Iodide 30 mg Tablet 60's", 'price': '₹516.00'}
# Title: Vitaminhaat Glucosamine Chondatrin 750 mg Capsule 120's
# Price: ₹1007.37
# Scraped product 84: {'title': "Vitaminhaat Glucosamine Chondatrin 750 mg Capsule 120's", 'price': '₹1007.37'}
# Title: Vitaminhaat Calciflex 600 mg Tablet 120's
# Price: ₹818.37
# Scraped product 85: {'title': "Vitaminhaat Calciflex 600 mg Tablet 120's", 'price': '₹818.37'}
# Title: Bold Care Superman Combo (Surge + Forever) 1's
# Price: ₹901.59
# Scraped product 86: {'title': "Bold Care Superman Combo (Surge + Forever) 1's", 'price': '₹901.59'}
# Title: Wellbeing Nutrition Melts Natural Vitamin D3+K2 (MK-7) with Vitashine, Resveterol and  MenaquinGold (30 Strips)
# Price: ₹597.08
# Scraped product 87: {'title': 'Wellbeing Nutrition Melts Natural Vitamin D3+K2 (MK-7) with Vitashine, Resveterol and  MenaquinGold (30 Strips)', 'price': '₹597.08'}
# Title: Inlife Magnesium Glycinate Veg Capsule 120's
# Price: ₹725.40
# Scraped product 88: {'title': "Inlife Magnesium Glycinate Veg Capsule 120's", 'price': '₹725.40'}
# Title: Briyo Coenzyme Q10 200 mg Softgel 60's
# Price: ₹787.25
# Scraped product 89: {'title': "Briyo Coenzyme Q10 200 mg Softgel 60's", 'price': '₹787.25'}
# Title: GNC Mega Men One Daily Tablet 60's
# Price: ₹853.44
# Scraped product 90: {'title': "GNC Mega Men One Daily Tablet 60's", 'price': '₹853.44'}
# Title: GNC Pro Performance Zinc Magnesium Tablet 60's
# Price: ₹659.34
# Scraped product 91: {'title': "GNC Pro Performance Zinc Magnesium Tablet 60's", 'price': '₹659.34'}
# Title: Nutrilite Cal Mag D Plus Tablet 90's
# Price: ₹826.02
# Scraped product 92: {'title': "Nutrilite Cal Mag D Plus Tablet 90's", 'price': '₹826.02'}
# Title: Swisse Ultiboost Iron Tablet 30's
# Price: ₹759.20
# Scraped product 93: {'title': "Swisse Ultiboost Iron Tablet 30's", 'price': '₹759.20'}
# Title: INLIFE Coenzyme Q10 + Bioperine Veg Capsule 60's
# Price: ₹1044.03
# Scraped product 94: {'title': "INLIFE Coenzyme Q10 + Bioperine Veg Capsule 60's", 'price': '₹1044.03'}
# Title: Healthvit Braineed Capsule 60's
# Price: ₹516.00
# Scraped product 95: {'title': "Healthvit Braineed Capsule 60's", 'price': '₹516.00'}
# Title: NUTRILITE KIDS CHEWABLE CONCENTRATED FRUITS AND VEGETABLES TABLET 60'S
# Price: ₹1384.50
# Scraped product 96: {'title': "NUTRILITE KIDS CHEWABLE CONCENTRATED FRUITS AND VEGETABLES TABLET 60'S", 'price': '₹1384.50'}
# Title: NUTRILITE BILBERRY WITH LUTEIN TABLET 60'S
# Price: ₹1848.75
# Scraped product 97: {'title': "NUTRILITE BILBERRY WITH LUTEIN TABLET 60'S", 'price': '₹1848.75'}
# Title: NUTRILITE CHERRY IRON TABLET 90'S
# Price: ₹909.00
# Scraped product 98: {'title': "NUTRILITE CHERRY IRON TABLET 90'S", 'price': '₹909.00'}
# Title: Nutrilite Cal Mag D Plus K2 Tablet 90's
# Price: ₹900.15
# Scraped product 99: {'title': "Nutrilite Cal Mag D Plus K2 Tablet 90's", 'price': '₹900.15'}
# Title: Nutrilite Vitamin B Yeast Plus Tablet 100's
# Price: ₹891.65
# Scraped product 100: {'title': "Nutrilite Vitamin B Yeast Plus Tablet 100's", 'price': '₹891.65'}
# Data saved to netmeds_c.xlsx.
