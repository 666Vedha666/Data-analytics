# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the WebDriver with headless option
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Uncomment for headless mode
options.add_argument('--no-sandbox')  # Recommended option for headless mode
options.add_argument('--disable-dev-shm-usage')  # Disable shared memory usage for better stability

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Start with the first page
base_url = 'https://www.ajio.com/search/?text=sunscreen'
driver.get(base_url)

# Initialize an empty list to store product data
product_data = []
max_products = 200  # Set limit to stop after collecting a certain number of products

def extract_product_details():
    products = driver.find_elements(By.CSS_SELECTOR, 'div.item.rilrtl-products-list__item')

    for product in products:
        if len(product_data) >= max_products:  # Stop if we have enough data
            return False

        product_info = {}

        try:
            # Extract product link (using correct CSS selector)
            link_elements = product.find_elements(By.CSS_SELECTOR, 'a')
            product_link = link_elements[0].get_attribute('href') if link_elements else 'No link'
            product_info['link'] = product_link
        except Exception:
            product_info['link'] = 'No link'

        # Now go to the individual product page to extract details
        if product_info['link'] != 'No link':
            try:
                # Open product link in a new tab
                driver.execute_script(f"window.open('{product_info['link']}', '_blank');")
                driver.switch_to.window(driver.window_handles[1])

                # Wait for the product page to load
                time.sleep(2)

                # Extract title
                try:
                    title_elements = driver.find_elements(By.CSS_SELECTOR, 'h2.brand-name')
                    product_info['title'] = title_elements[0].text if title_elements else 'No title'
                except Exception:
                    product_info['title'] = 'No title'

                # Extract price
                try:
                    price_elements = driver.find_elements(By.CSS_SELECTOR, 'div.prod-sp')
                    product_info['price'] = price_elements[0].text if price_elements else 'No price'
                except Exception:
                    product_info['price'] = 'No price'

                # Extract ratings
                try:
                    rating_elements = driver.find_elements(By.CSS_SELECTOR, 'span._3c5q0')
                    product_info['rating'] = rating_elements[0].text if rating_elements else 'No rating'
                except Exception:
                    product_info['rating'] = 'No rating'

                # Extract number of reviews
                try:
                    reviews_elements = driver.find_elements(By.CSS_SELECTOR, 'span._38RNg')
                    product_info['reviews'] = reviews_elements[0].text if reviews_elements else 'No reviews'
                except Exception:
                    product_info['reviews'] = 'No reviews'

                print(f"Scraped details from product page: {product_info}")

                # Close the product tab and switch back to the search results tab
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

                # Wait for the page to return to the main search
                time.sleep(2)

            except Exception as e:
                print(f"Error while scraping product page: {e}")
                product_info['title'] = 'No title'
                product_info['price'] = 'No price'
                product_info['rating'] = 'No rating'
                product_info['reviews'] = 'No reviews'

        # Append the product info to the list
        product_data.append(product_info)

        # Print product information to show the scraping progress
        print(f"Scraped product {len(product_data)}: {product_info}")

    return True  # Continue scraping


# Scroll the page and extract products until we reach the max product limit
scroll_pause_time = 2  # Adjust if needed for smoother scrolling
while len(product_data) < max_products:
    extract_success = extract_product_details()

    if not extract_success:
        break

    # Scroll down to load more products
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Wait for the page to load new products
    time.sleep(scroll_pause_time)

# Close the driver after scraping
driver.quit()

# Convert the product data into a DataFrame and save it to an Excel file
df = pd.DataFrame(product_data)
df.to_excel('ajio_sun.xlsx', index=False)  # Use .to_excel() for Excel format
print('Data saved to ajio_sun.xlsx.')
# Out:
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-hyaluronic-sunscreen-aqua-gel-spf-50-pa-/p/4936821460_multi', 'title': 'THE DERMA CO', 'price': '₹399', 'rating': '4.2', 'reviews': '569 Ratings'}
# Scraped product 1: {'link': 'https://www.ajio.com/the-derma-co-hyaluronic-sunscreen-aqua-gel-spf-50-pa-/p/4936821460_multi', 'title': 'THE DERMA CO', 'price': '₹399', 'rating': '4.2', 'reviews': '569 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/minimalist-spf-50-pa---sunscreen-with-multi-vitamin/p/4924945590_multi', 'title': 'MINIMALIST', 'price': '₹379', 'rating': '4', 'reviews': '891 Ratings'}
# Scraped product 2: {'link': 'https://www.ajio.com/minimalist-spf-50-pa---sunscreen-with-multi-vitamin/p/4924945590_multi', 'title': 'MINIMALIST', 'price': '₹379', 'rating': '4', 'reviews': '891 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/wishcare-spf-50-sunscreen-body-lotion--broad-spectrum-for-men--women/p/4936939200_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4.3', 'reviews': '150 Ratings'}
# Scraped product 3: {'link': 'https://www.ajio.com/wishcare-spf-50-sunscreen-body-lotion--broad-spectrum-for-men--women/p/4936939200_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4.3', 'reviews': '150 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/cetaphil-sun-light-gel-spf50-/p/4925194880_multi', 'title': 'CETAPHIL', 'price': '₹1,052', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped product 4: {'link': 'https://www.ajio.com/cetaphil-sun-light-gel-spf50-/p/4925194880_multi', 'title': 'CETAPHIL', 'price': '₹1,052', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4907506410_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹299', 'rating': '4', 'reviews': '161 Ratings'}
# Scraped product 5: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4907506410_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹299', 'rating': '4', 'reviews': '161 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-protect-moisture-lotion-spf-30/p/4909354960_multi', 'title': 'NIVEA', 'price': '₹259', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped product 6: {'link': 'https://www.ajio.com/nivea-sun-protect-moisture-lotion-spf-30/p/4909354960_multi', 'title': 'NIVEA', 'price': '₹259', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-active-sunscreen/p/4925004180_multi', 'title': 'THE FACE SHOP', 'price': '₹743', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped product 7: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-active-sunscreen/p/4925004180_multi', 'title': 'THE FACE SHOP', 'price': '₹743', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-ultra-light-indian-sunscreen-80-ml/p/4919382900_multi', 'title': 'MAMAEARTH', 'price': '₹389', 'rating': '3.8', 'reviews': '63 Ratings'}
# Scraped product 8: {'link': 'https://www.ajio.com/mamaearth-ultra-light-indian-sunscreen-80-ml/p/4919382900_multi', 'title': 'MAMAEARTH', 'price': '₹389', 'rating': '3.8', 'reviews': '63 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4905683350_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹780', 'rating': '3.6', 'reviews': '68 Ratings'}
# Scraped product 9: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4905683350_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹780', 'rating': '3.6', 'reviews': '68 Ratings'}
# Scraped details from product page: {'link': 'https://ajio.com/s/starting-at-rs-799-5523-66111?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 10: {'link': 'https://ajio.com/s/starting-at-rs-799-5523-66111?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-oxybenzone--omc-free-sunscreen/p/4926542320_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹395', 'rating': '4.2', 'reviews': '65 Ratings'}
# Scraped product 11: {'link': 'https://www.ajio.com/re-equil-oxybenzone--omc-free-sunscreen/p/4926542320_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹395', 'rating': '4.2', 'reviews': '65 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-kojic-acid-daily-glo-body-serum-lotion/p/4936821490_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '35 Ratings'}
# Scraped product 12: {'link': 'https://www.ajio.com/the-derma-co-kojic-acid-daily-glo-body-serum-lotion/p/4936821490_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '35 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-50/p/4909354980_multi', 'title': 'NIVEA', 'price': '₹391', 'rating': '3.6', 'reviews': '39 Ratings'}
# Scraped product 13: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-50/p/4909354980_multi', 'title': 'NIVEA', 'price': '₹391', 'rating': '3.6', 'reviews': '39 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-ultra-matte-dry-touch-sunscreen-gel/p/4926555960_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹645', 'rating': '4.3', 'reviews': '93 Ratings'}
# Scraped product 14: {'link': 'https://www.ajio.com/re-equil-ultra-matte-dry-touch-sunscreen-gel/p/4926555960_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹645', 'rating': '4.3', 'reviews': '93 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/wishcare-invisible-gel-sunscreen-spf-50-pa----broad-spectrum-protection-with-no-white-cast/p/4936939130_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4', 'reviews': '49 Ratings'}
# Scraped product 15: {'link': 'https://www.ajio.com/wishcare-invisible-gel-sunscreen-spf-50-pa----broad-spectrum-protection-with-no-white-cast/p/4936939130_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4', 'reviews': '49 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094560_multi', 'title': 'LAKME', 'price': '₹333', 'rating': '4.9', 'reviews': '7 Ratings'}
# Scraped product 16: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094560_multi', 'title': 'LAKME', 'price': '₹333', 'rating': '4.9', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/minimalist-spf-60-pa---sunscreen-with-antioxidant/p/4924948210_multi', 'title': 'MINIMALIST', 'price': '₹569', 'rating': '3.9', 'reviews': '226 Ratings'}
# Scraped product 17: {'link': 'https://www.ajio.com/minimalist-spf-60-pa---sunscreen-with-antioxidant/p/4924948210_multi', 'title': 'MINIMALIST', 'price': '₹569', 'rating': '3.9', 'reviews': '226 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-24-ultra-matte-lotion/p/4900024890_multi', 'title': 'LAKME', 'price': '₹301', 'rating': '3.8', 'reviews': '46 Ratings'}
# Scraped product 18: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-24-ultra-matte-lotion/p/4900024890_multi', 'title': 'LAKME', 'price': '₹301', 'rating': '3.8', 'reviews': '46 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-50-spf/p/4916484510_multi', 'title': 'LAKME', 'price': '₹419', 'rating': '4', 'reviews': '139 Ratings'}
# Scraped product 19: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-50-spf/p/4916484510_multi', 'title': 'LAKME', 'price': '₹419', 'rating': '4', 'reviews': '139 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-hydragel-indian-sunscreen-spf-50-50-g/p/4919382950_multi', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '3.6', 'reviews': '70 Ratings'}
# Scraped product 20: {'link': 'https://www.ajio.com/mamaearth-hydragel-indian-sunscreen-spf-50-50-g/p/4919382950_multi', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '3.6', 'reviews': '70 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/bioderma-photoderm-akn-mat-sunscreen-spf-30/p/4936935590_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,749', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 21: {'link': 'https://www.ajio.com/bioderma-photoderm-akn-mat-sunscreen-spf-30/p/4936935590_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,749', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-ultra-matte-sunscreen-gel-spf-60-pa-/p/4936822060_multi', 'title': 'THE DERMA CO', 'price': '₹552', 'rating': '4.3', 'reviews': '32 Ratings'}
# Scraped product 22: {'link': 'https://www.ajio.com/the-derma-co-ultra-matte-sunscreen-gel-spf-60-pa-/p/4936822060_multi', 'title': 'THE DERMA CO', 'price': '₹552', 'rating': '4.3', 'reviews': '32 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-no-shine-hydrating-sun-cream/p/4928743980_multi', 'title': 'THE FACE SHOP', 'price': '₹803', 'rating': '4.5', 'reviews': '11 Ratings'}
# Scraped product 23: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-no-shine-hydrating-sun-cream/p/4928743980_multi', 'title': 'THE FACE SHOP', 'price': '₹803', 'rating': '4.5', 'reviews': '11 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094550_multi', 'title': 'LAKME', 'price': '₹224', 'rating': '4.1', 'reviews': '38 Ratings'}
# Scraped product 24: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094550_multi', 'title': 'LAKME', 'price': '₹224', 'rating': '4.1', 'reviews': '38 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-50-light-weight-gel/p/4919390660_multi', 'title': 'LAKME', 'price': '₹399', 'rating': '3.7', 'reviews': '15 Ratings'}
# Scraped product 25: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-50-light-weight-gel/p/4919390660_multi', 'title': 'LAKME', 'price': '₹399', 'rating': '3.7', 'reviews': '15 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-professional-phyto-rx-silk-matte-uv-defence-sunblock-with-spf-50-pa--/p/4919387300_multi', 'title': 'LOTUS PROFESSIONAL', 'price': '₹716', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 26: {'link': 'https://www.ajio.com/lotus-professional-phyto-rx-silk-matte-uv-defence-sunblock-with-spf-50-pa--/p/4919387300_multi', 'title': 'LOTUS PROFESSIONAL', 'price': '₹716', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lisen-soothing-shade-spf-50--pa---sunscreen/p/4926529840_multicolor', 'title': 'LISEN', 'price': 'MRP₹1,500', 'rating': '4.7', 'reviews': '3 Ratings'}
# Scraped product 27: {'link': 'https://www.ajio.com/lisen-soothing-shade-spf-50--pa---sunscreen/p/4926529840_multicolor', 'title': 'LISEN', 'price': 'MRP₹1,500', 'rating': '4.7', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/forest-essentials-turmeric--basil-leaf-tender-coconut-water-sun-fluid-with-spf-50-pa--/p/4937172330_multi', 'title': 'FOREST ESSENTIALS', 'price': 'MRP₹1,395', 'rating': '4.3', 'reviews': '24 Ratings'}
# Scraped product 28: {'link': 'https://www.ajio.com/forest-essentials-turmeric--basil-leaf-tender-coconut-water-sun-fluid-with-spf-50-pa--/p/4937172330_multi', 'title': 'FOREST ESSENTIALS', 'price': 'MRP₹1,395', 'rating': '4.3', 'reviews': '24 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-antitan-body-lotion-spf-25--150-ml/p/4912027080_multi', 'title': 'VLCC', 'price': '₹282', 'rating': '4.1', 'reviews': '26 Ratings'}
# Scraped product 29: {'link': 'https://www.ajio.com/vlcc-antitan-body-lotion-spf-25--150-ml/p/4912027080_multi', 'title': 'VLCC', 'price': '₹282', 'rating': '4.1', 'reviews': '26 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-gel-sunscreen/p/4913699800_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.1', 'reviews': '23 Ratings'}
# Scraped product 30: {'link': 'https://www.ajio.com/lakme-gel-sunscreen/p/4913699800_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.1', 'reviews': '23 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-cream/p/4909360450_multi', 'title': 'VLCC', 'price': '₹198', 'rating': '3.5', 'reviews': '40 Ratings'}
# Scraped product 31: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-cream/p/4909360450_multi', 'title': 'VLCC', 'price': '₹198', 'rating': '3.5', 'reviews': '40 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-co-being-women-set-of-2-sunscreen-spray-spf-50/p/700258706_white', 'title': 'THE CO BEING', 'price': '₹1,119', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 32: {'link': 'https://www.ajio.com/the-co-being-women-set-of-2-sunscreen-spray-spf-50/p/700258706_white', 'title': 'THE CO BEING', 'price': '₹1,119', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-spf-50/p/4919390790_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.8', 'reviews': '64 Ratings'}
# Scraped product 33: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-spf-50/p/4919390790_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.8', 'reviews': '64 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-perfect-sunscreen-ex/p/4928743970_multi', 'title': 'THE FACE SHOP', 'price': '₹1,004', 'rating': '4', 'reviews': '3 Ratings'}
# Scraped product 34: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-perfect-sunscreen-ex/p/4928743970_multi', 'title': 'THE FACE SHOP', 'price': '₹1,004', 'rating': '4', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-3d-youth-boost-spf40-sunscreen-gel-creme--50-g/p/4914346700_multi', 'title': 'VLCC', 'price': '₹240', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 35: {'link': 'https://www.ajio.com/vlcc-3d-youth-boost-spf40-sunscreen-gel-creme--50-g/p/4914346700_multi', 'title': 'VLCC', 'price': '₹240', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-water-sun-cream-spf-50-pa--/p/4932881250_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped product 36: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-water-sun-cream-spf-50-pa--/p/4932881250_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/la-shield-fisico-spf-50--pa--sunscreen-gel/p/4919462330_multi', 'title': 'LA SHIELD', 'price': '₹594', 'rating': '4.1', 'reviews': '48 Ratings'}
# Scraped product 37: {'link': 'https://www.ajio.com/la-shield-fisico-spf-50--pa--sunscreen-gel/p/4919462330_multi', 'title': 'LA SHIELD', 'price': '₹594', 'rating': '4.1', 'reviews': '48 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/fixderma-shadow-spf-50-face-cream/p/4932890110_multicolor', 'title': 'FIXDERMA', 'price': '₹319', 'rating': '4.4', 'reviews': '59 Ratings'}
# Scraped product 38: {'link': 'https://www.ajio.com/fixderma-shadow-spf-50-face-cream/p/4932890110_multicolor', 'title': 'FIXDERMA', 'price': '₹319', 'rating': '4.4', 'reviews': '59 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-sheer-zinc-tinted-mineral-sunscreen/p/4926557740_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹695', 'rating': '5', 'reviews': '6 Ratings'}
# Scraped product 39: {'link': 'https://www.ajio.com/re-equil-sheer-zinc-tinted-mineral-sunscreen/p/4926557740_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹695', 'rating': '5', 'reviews': '6 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-aqua-glow-hydrating-sunscreen-gel/p/4925067060_multicolor', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '4.1', 'reviews': '17 Ratings'}
# Scraped product 40: {'link': 'https://www.ajio.com/mamaearth-aqua-glow-hydrating-sunscreen-gel/p/4925067060_multicolor', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '4.1', 'reviews': '17 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-light-sun-essence-spf-30-pa-/p/4932881330_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.5', 'reviews': '2 Ratings'}
# Scraped product 41: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-light-sun-essence-spf-30-pa-/p/4932881330_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.5', 'reviews': '2 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/bioderma-photoderm-cream-sunscreen-spf-50-/p/4936935610_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,099', 'rating': '4.3', 'reviews': '29 Ratings'}
# Scraped product 42: {'link': 'https://www.ajio.com/bioderma-photoderm-cream-sunscreen-spf-50-/p/4936935610_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,099', 'rating': '4.3', 'reviews': '29 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-safe-sun-in-mattelook-daily-sunblock-pa--spf40/p/4909591920_multi', 'title': 'LOTUS', 'price': '₹360', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped product 43: {'link': 'https://www.ajio.com/lotus-safe-sun-in-mattelook-daily-sunblock-pa--spf40/p/4909591920_multi', 'title': 'LOTUS', 'price': '₹360', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-30/p/4909354970_multi', 'title': 'NIVEA', 'price': '₹384', 'rating': '4.1', 'reviews': '27 Ratings'}
# Scraped product 44: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-30/p/4909354970_multi', 'title': 'NIVEA', 'price': '₹384', 'rating': '4.1', 'reviews': '27 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-safe-sun-sun-block-cream-pa--spf30/p/4909591900_multi', 'title': 'LOTUS', 'price': '₹308', 'rating': '3.6', 'reviews': '7 Ratings'}
# Scraped product 45: {'link': 'https://www.ajio.com/lotus-safe-sun-sun-block-cream-pa--spf30/p/4909591900_multi', 'title': 'LOTUS', 'price': '₹308', 'rating': '3.6', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/jovees-sun-guard-3-in-1-spf-60-pa--paraben-free-matte-lotion/p/4925060570_multi', 'title': 'JOVEES', 'price': 'MRP₹365', 'rating': '3.7', 'reviews': '120 Ratings'}
# Scraped product 46: {'link': 'https://www.ajio.com/jovees-sun-guard-3-in-1-spf-60-pa--paraben-free-matte-lotion/p/4925060570_multi', 'title': 'JOVEES', 'price': 'MRP₹365', 'rating': '3.7', 'reviews': '120 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-hyaluronic-sunscreen-aqua-gel-spf-50-pa-/p/4936821460_multi', 'title': 'THE DERMA CO', 'price': '₹399', 'rating': '4.2', 'reviews': '569 Ratings'}
# Scraped product 47: {'link': 'https://www.ajio.com/the-derma-co-hyaluronic-sunscreen-aqua-gel-spf-50-pa-/p/4936821460_multi', 'title': 'THE DERMA CO', 'price': '₹399', 'rating': '4.2', 'reviews': '569 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/minimalist-spf-50-pa---sunscreen-with-multi-vitamin/p/4924945590_multi', 'title': 'MINIMALIST', 'price': '₹379', 'rating': '4', 'reviews': '891 Ratings'}
# Scraped product 48: {'link': 'https://www.ajio.com/minimalist-spf-50-pa---sunscreen-with-multi-vitamin/p/4924945590_multi', 'title': 'MINIMALIST', 'price': '₹379', 'rating': '4', 'reviews': '891 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/wishcare-spf-50-sunscreen-body-lotion--broad-spectrum-for-men--women/p/4936939200_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4.3', 'reviews': '150 Ratings'}
# Scraped product 49: {'link': 'https://www.ajio.com/wishcare-spf-50-sunscreen-body-lotion--broad-spectrum-for-men--women/p/4936939200_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4.3', 'reviews': '150 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/cetaphil-sun-light-gel-spf50-/p/4925194880_multi', 'title': 'CETAPHIL', 'price': '₹1,052', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped product 50: {'link': 'https://www.ajio.com/cetaphil-sun-light-gel-spf50-/p/4925194880_multi', 'title': 'CETAPHIL', 'price': '₹1,052', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4907506410_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹299', 'rating': '4', 'reviews': '161 Ratings'}
# Scraped product 51: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4907506410_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹299', 'rating': '4', 'reviews': '161 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-protect-moisture-lotion-spf-30/p/4909354960_multi', 'title': 'NIVEA', 'price': '₹259', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped product 52: {'link': 'https://www.ajio.com/nivea-sun-protect-moisture-lotion-spf-30/p/4909354960_multi', 'title': 'NIVEA', 'price': '₹259', 'rating': '3.9', 'reviews': '16 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-active-sunscreen/p/4925004180_multi', 'title': 'THE FACE SHOP', 'price': '₹743', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped product 53: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-active-sunscreen/p/4925004180_multi', 'title': 'THE FACE SHOP', 'price': '₹743', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-ultra-light-indian-sunscreen-80-ml/p/4919382900_multi', 'title': 'MAMAEARTH', 'price': '₹389', 'rating': '3.8', 'reviews': '63 Ratings'}
# Scraped product 54: {'link': 'https://www.ajio.com/mamaearth-ultra-light-indian-sunscreen-80-ml/p/4919382900_multi', 'title': 'MAMAEARTH', 'price': '₹389', 'rating': '3.8', 'reviews': '63 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4905683350_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹780', 'rating': '3.6', 'reviews': '68 Ratings'}
# Scraped product 55: {'link': 'https://www.ajio.com/neutrogena-ultra-sheer-dry-touch-suncream/p/4905683350_multicolor', 'title': 'NEUTROGENA', 'price': 'MRP₹780', 'rating': '3.6', 'reviews': '68 Ratings'}
# Scraped details from product page: {'link': 'https://ajio.com/s/starting-at-rs-799-5523-66111?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 56: {'link': 'https://ajio.com/s/starting-at-rs-799-5523-66111?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-oxybenzone--omc-free-sunscreen/p/4926542320_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹395', 'rating': '4.2', 'reviews': '65 Ratings'}
# Scraped product 57: {'link': 'https://www.ajio.com/re-equil-oxybenzone--omc-free-sunscreen/p/4926542320_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹395', 'rating': '4.2', 'reviews': '65 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-kojic-acid-daily-glo-body-serum-lotion/p/4936821490_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '35 Ratings'}
# Scraped product 58: {'link': 'https://www.ajio.com/the-derma-co-kojic-acid-daily-glo-body-serum-lotion/p/4936821490_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '35 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-50/p/4909354980_multi', 'title': 'NIVEA', 'price': '₹391', 'rating': '3.6', 'reviews': '39 Ratings'}
# Scraped product 59: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-50/p/4909354980_multi', 'title': 'NIVEA', 'price': '₹391', 'rating': '3.6', 'reviews': '39 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-ultra-matte-dry-touch-sunscreen-gel/p/4926555960_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹645', 'rating': '4.3', 'reviews': '93 Ratings'}
# Scraped product 60: {'link': 'https://www.ajio.com/re-equil-ultra-matte-dry-touch-sunscreen-gel/p/4926555960_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹645', 'rating': '4.3', 'reviews': '93 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/wishcare-invisible-gel-sunscreen-spf-50-pa----broad-spectrum-protection-with-no-white-cast/p/4936939130_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4', 'reviews': '49 Ratings'}
# Scraped product 61: {'link': 'https://www.ajio.com/wishcare-invisible-gel-sunscreen-spf-50-pa----broad-spectrum-protection-with-no-white-cast/p/4936939130_multi', 'title': 'WISHCARE', 'price': '₹399', 'rating': '4', 'reviews': '49 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094560_multi', 'title': 'LAKME', 'price': '₹333', 'rating': '4.9', 'reviews': '7 Ratings'}
# Scraped product 62: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094560_multi', 'title': 'LAKME', 'price': '₹333', 'rating': '4.9', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/minimalist-spf-60-pa---sunscreen-with-antioxidant/p/4924948210_multi', 'title': 'MINIMALIST', 'price': '₹569', 'rating': '3.9', 'reviews': '226 Ratings'}
# Scraped product 63: {'link': 'https://www.ajio.com/minimalist-spf-60-pa---sunscreen-with-antioxidant/p/4924948210_multi', 'title': 'MINIMALIST', 'price': '₹569', 'rating': '3.9', 'reviews': '226 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-24-ultra-matte-lotion/p/4900024890_multi', 'title': 'LAKME', 'price': '₹301', 'rating': '3.8', 'reviews': '46 Ratings'}
# Scraped product 64: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-24-ultra-matte-lotion/p/4900024890_multi', 'title': 'LAKME', 'price': '₹301', 'rating': '3.8', 'reviews': '46 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-50-spf/p/4916484510_multi', 'title': 'LAKME', 'price': '₹419', 'rating': '4', 'reviews': '139 Ratings'}
# Scraped product 65: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-50-spf/p/4916484510_multi', 'title': 'LAKME', 'price': '₹419', 'rating': '4', 'reviews': '139 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-hydragel-indian-sunscreen-spf-50-50-g/p/4919382950_multi', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '3.6', 'reviews': '70 Ratings'}
# Scraped product 66: {'link': 'https://www.ajio.com/mamaearth-hydragel-indian-sunscreen-spf-50-50-g/p/4919382950_multi', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '3.6', 'reviews': '70 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/bioderma-photoderm-akn-mat-sunscreen-spf-30/p/4936935590_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,749', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 67: {'link': 'https://www.ajio.com/bioderma-photoderm-akn-mat-sunscreen-spf-30/p/4936935590_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,749', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-ultra-matte-sunscreen-gel-spf-60-pa-/p/4936822060_multi', 'title': 'THE DERMA CO', 'price': '₹552', 'rating': '4.3', 'reviews': '32 Ratings'}
# Scraped product 68: {'link': 'https://www.ajio.com/the-derma-co-ultra-matte-sunscreen-gel-spf-60-pa-/p/4936822060_multi', 'title': 'THE DERMA CO', 'price': '₹552', 'rating': '4.3', 'reviews': '32 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-no-shine-hydrating-sun-cream/p/4928743980_multi', 'title': 'THE FACE SHOP', 'price': '₹803', 'rating': '4.5', 'reviews': '11 Ratings'}
# Scraped product 69: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-no-shine-hydrating-sun-cream/p/4928743980_multi', 'title': 'THE FACE SHOP', 'price': '₹803', 'rating': '4.5', 'reviews': '11 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094550_multi', 'title': 'LAKME', 'price': '₹224', 'rating': '4.1', 'reviews': '38 Ratings'}
# Scraped product 70: {'link': 'https://www.ajio.com/lakme-sun-expert-ultra-matte-lotion/p/4908094550_multi', 'title': 'LAKME', 'price': '₹224', 'rating': '4.1', 'reviews': '38 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-50-light-weight-gel/p/4919390660_multi', 'title': 'LAKME', 'price': '₹399', 'rating': '3.7', 'reviews': '15 Ratings'}
# Scraped product 71: {'link': 'https://www.ajio.com/lakme-sun-expert-spf-50-light-weight-gel/p/4919390660_multi', 'title': 'LAKME', 'price': '₹399', 'rating': '3.7', 'reviews': '15 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-professional-phyto-rx-silk-matte-uv-defence-sunblock-with-spf-50-pa--/p/4919387300_multi', 'title': 'LOTUS PROFESSIONAL', 'price': '₹716', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 72: {'link': 'https://www.ajio.com/lotus-professional-phyto-rx-silk-matte-uv-defence-sunblock-with-spf-50-pa--/p/4919387300_multi', 'title': 'LOTUS PROFESSIONAL', 'price': '₹716', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lisen-soothing-shade-spf-50--pa---sunscreen/p/4926529840_multicolor', 'title': 'LISEN', 'price': 'MRP₹1,500', 'rating': '4.7', 'reviews': '3 Ratings'}
# Scraped product 73: {'link': 'https://www.ajio.com/lisen-soothing-shade-spf-50--pa---sunscreen/p/4926529840_multicolor', 'title': 'LISEN', 'price': 'MRP₹1,500', 'rating': '4.7', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/forest-essentials-turmeric--basil-leaf-tender-coconut-water-sun-fluid-with-spf-50-pa--/p/4937172330_multi', 'title': 'FOREST ESSENTIALS', 'price': 'MRP₹1,395', 'rating': '4.3', 'reviews': '24 Ratings'}
# Scraped product 74: {'link': 'https://www.ajio.com/forest-essentials-turmeric--basil-leaf-tender-coconut-water-sun-fluid-with-spf-50-pa--/p/4937172330_multi', 'title': 'FOREST ESSENTIALS', 'price': 'MRP₹1,395', 'rating': '4.3', 'reviews': '24 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-antitan-body-lotion-spf-25--150-ml/p/4912027080_multi', 'title': 'VLCC', 'price': '₹282', 'rating': '4.1', 'reviews': '26 Ratings'}
# Scraped product 75: {'link': 'https://www.ajio.com/vlcc-antitan-body-lotion-spf-25--150-ml/p/4912027080_multi', 'title': 'VLCC', 'price': '₹282', 'rating': '4.1', 'reviews': '26 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-gel-sunscreen/p/4913699800_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.1', 'reviews': '23 Ratings'}
# Scraped product 76: {'link': 'https://www.ajio.com/lakme-gel-sunscreen/p/4913699800_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.1', 'reviews': '23 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-cream/p/4909360450_multi', 'title': 'VLCC', 'price': '₹198', 'rating': '3.5', 'reviews': '40 Ratings'}
# Scraped product 77: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-cream/p/4909360450_multi', 'title': 'VLCC', 'price': '₹198', 'rating': '3.5', 'reviews': '40 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-co-being-women-set-of-2-sunscreen-spray-spf-50/p/700258706_white', 'title': 'THE CO BEING', 'price': '₹1,119', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 78: {'link': 'https://www.ajio.com/the-co-being-women-set-of-2-sunscreen-spray-spf-50/p/700258706_white', 'title': 'THE CO BEING', 'price': '₹1,119', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-spf-50/p/4919390790_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.8', 'reviews': '64 Ratings'}
# Scraped product 79: {'link': 'https://www.ajio.com/lakme-sun-expert-tinted-sunscreen-spf-50/p/4919390790_multi', 'title': 'LAKME', 'price': '₹274', 'rating': '3.8', 'reviews': '64 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-perfect-sunscreen-ex/p/4928743970_multi', 'title': 'THE FACE SHOP', 'price': '₹1,004', 'rating': '4', 'reviews': '3 Ratings'}
# Scraped product 80: {'link': 'https://www.ajio.com/the-face-shop-naturalsun-eco-super-perfect-sunscreen-ex/p/4928743970_multi', 'title': 'THE FACE SHOP', 'price': '₹1,004', 'rating': '4', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-3d-youth-boost-spf40-sunscreen-gel-creme--50-g/p/4914346700_multi', 'title': 'VLCC', 'price': '₹240', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 81: {'link': 'https://www.ajio.com/vlcc-3d-youth-boost-spf40-sunscreen-gel-creme--50-g/p/4914346700_multi', 'title': 'VLCC', 'price': '₹240', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-water-sun-cream-spf-50-pa--/p/4932881250_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped product 82: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-water-sun-cream-spf-50-pa--/p/4932881250_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/la-shield-fisico-spf-50--pa--sunscreen-gel/p/4919462330_multi', 'title': 'LA SHIELD', 'price': '₹594', 'rating': '4.1', 'reviews': '48 Ratings'}
# Scraped product 83: {'link': 'https://www.ajio.com/la-shield-fisico-spf-50--pa--sunscreen-gel/p/4919462330_multi', 'title': 'LA SHIELD', 'price': '₹594', 'rating': '4.1', 'reviews': '48 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/fixderma-shadow-spf-50-face-cream/p/4932890110_multicolor', 'title': 'FIXDERMA', 'price': '₹319', 'rating': '4.4', 'reviews': '59 Ratings'}
# Scraped product 84: {'link': 'https://www.ajio.com/fixderma-shadow-spf-50-face-cream/p/4932890110_multicolor', 'title': 'FIXDERMA', 'price': '₹319', 'rating': '4.4', 'reviews': '59 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/re-equil-sheer-zinc-tinted-mineral-sunscreen/p/4926557740_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹695', 'rating': '5', 'reviews': '6 Ratings'}
# Scraped product 85: {'link': 'https://www.ajio.com/re-equil-sheer-zinc-tinted-mineral-sunscreen/p/4926557740_multicolor', 'title': "RE'EQUIL", 'price': 'MRP₹695', 'rating': '5', 'reviews': '6 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/mamaearth-aqua-glow-hydrating-sunscreen-gel/p/4925067060_multicolor', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '4.1', 'reviews': '17 Ratings'}
# Scraped product 86: {'link': 'https://www.ajio.com/mamaearth-aqua-glow-hydrating-sunscreen-gel/p/4925067060_multicolor', 'title': 'MAMAEARTH', 'price': '₹319', 'rating': '4.1', 'reviews': '17 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-light-sun-essence-spf-30-pa-/p/4932881330_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.5', 'reviews': '2 Ratings'}
# Scraped product 87: {'link': 'https://www.ajio.com/thank-you-farmer-women-sun-project-light-sun-essence-spf-30-pa-/p/4932881330_multi', 'title': 'THANK YOU FARMER', 'price': '₹1,727', 'rating': '4.5', 'reviews': '2 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/bioderma-photoderm-cream-sunscreen-spf-50-/p/4936935610_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,099', 'rating': '4.3', 'reviews': '29 Ratings'}
# Scraped product 88: {'link': 'https://www.ajio.com/bioderma-photoderm-cream-sunscreen-spf-50-/p/4936935610_multi', 'title': 'BIODERMA', 'price': 'MRP₹1,099', 'rating': '4.3', 'reviews': '29 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-safe-sun-in-mattelook-daily-sunblock-pa--spf40/p/4909591920_multi', 'title': 'LOTUS', 'price': '₹360', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped product 89: {'link': 'https://www.ajio.com/lotus-safe-sun-in-mattelook-daily-sunblock-pa--spf40/p/4909591920_multi', 'title': 'LOTUS', 'price': '₹360', 'rating': '3.7', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-30/p/4909354970_multi', 'title': 'NIVEA', 'price': '₹384', 'rating': '4.1', 'reviews': '27 Ratings'}
# Scraped product 90: {'link': 'https://www.ajio.com/nivea-sun-lotion-spf-30/p/4909354970_multi', 'title': 'NIVEA', 'price': '₹384', 'rating': '4.1', 'reviews': '27 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lotus-safe-sun-sun-block-cream-pa--spf30/p/4909591900_multi', 'title': 'LOTUS', 'price': '₹308', 'rating': '3.6', 'reviews': '7 Ratings'}
# Scraped product 91: {'link': 'https://www.ajio.com/lotus-safe-sun-sun-block-cream-pa--spf30/p/4909591900_multi', 'title': 'LOTUS', 'price': '₹308', 'rating': '3.6', 'reviews': '7 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/jovees-sun-guard-3-in-1-spf-60-pa--paraben-free-matte-lotion/p/4925060570_multi', 'title': 'JOVEES', 'price': 'MRP₹365', 'rating': '3.7', 'reviews': '120 Ratings'}
# Scraped product 92: {'link': 'https://www.ajio.com/jovees-sun-guard-3-in-1-spf-60-pa--paraben-free-matte-lotion/p/4925060570_multi', 'title': 'JOVEES', 'price': 'MRP₹365', 'rating': '3.7', 'reviews': '120 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/keya-seth-aromatherapy-aromatherapy-umbrella-sunscreen-powder/p/4926550260_multicolor', 'title': 'KEYA SETH AROMATHERAPY', 'price': 'MRP₹349', 'rating': '3.8', 'reviews': '6 Ratings'}
# Scraped product 93: {'link': 'https://www.ajio.com/keya-seth-aromatherapy-aromatherapy-umbrella-sunscreen-powder/p/4926550260_multicolor', 'title': 'KEYA SETH AROMATHERAPY', 'price': 'MRP₹349', 'rating': '3.8', 'reviews': '6 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-creme/p/4909360070_multi', 'title': 'VLCC', 'price': '₹336', 'rating': '4', 'reviews': '41 Ratings'}
# Scraped product 94: {'link': 'https://www.ajio.com/vlcc-matte-look-spf-30-sun-screen-gel-creme/p/4909360070_multi', 'title': 'VLCC', 'price': '₹336', 'rating': '4', 'reviews': '41 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert/p/4909204950_multi', 'title': 'LAKME', 'price': '₹385', 'rating': '3.5', 'reviews': '53 Ratings'}
# Scraped product 95: {'link': 'https://www.ajio.com/lakme-sun-expert/p/4909204950_multi', 'title': 'LAKME', 'price': '₹385', 'rating': '3.5', 'reviews': '53 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lakme-sun-expert/p/4913218490_multi', 'title': 'LAKME', 'price': '₹244', 'rating': '3.3', 'reviews': '87 Ratings'}
# Scraped product 96: {'link': 'https://www.ajio.com/lakme-sun-expert/p/4913218490_multi', 'title': 'LAKME', 'price': '₹244', 'rating': '3.3', 'reviews': '87 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/the-derma-co-salicylic-acid-daily-exfoliating-body-serum-lotion/p/4936821500_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '10 Ratings'}
# Scraped product 97: {'link': 'https://www.ajio.com/the-derma-co-salicylic-acid-daily-exfoliating-body-serum-lotion/p/4936821500_multi', 'title': 'THE DERMA CO', 'price': '₹319', 'rating': '4.1', 'reviews': '10 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/fixderma-shadow-spf-30-a-gel/p/4936365380_multi', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Error while scraping product page: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=128.0.6613.120)
# Stacktrace:
# 	GetHandleVerifier [0x00D98213+26163]
# 	(No symbol) [0x00D29CC4]
# 	(No symbol) [0x00C224C3]
# 	(No symbol) [0x00C0BE90]
# 	(No symbol) [0x00C0CC3D]
# 	(No symbol) [0x00C229D2]
# 	(No symbol) [0x00BFDEB5]
# 	(No symbol) [0x00C9707E]
# 	(No symbol) [0x00C8AC83]
# 	(No symbol) [0x00C5BE89]
# 	(No symbol) [0x00C5C8CD]
# 	GetHandleVerifier [0x0106D313+2996019]
# 	GetHandleVerifier [0x010C1B89+3342249]
# 	GetHandleVerifier [0x00E27AEF+614159]
# 	GetHandleVerifier [0x00E2F17C+644508]
# 	(No symbol) [0x00D327FD]
# 	(No symbol) [0x00D2F6F8]
# 	(No symbol) [0x00D2F895]
# 	(No symbol) [0x00D21C16]
# 	BaseThreadInitThunk [0x76167BA9+25]
# 	RtlInitializeExceptionChain [0x777BC11B+107]
# 	RtlClearBits [0x777BC09F+191]
#
# Scraped product 98: {'link': 'https://www.ajio.com/fixderma-shadow-spf-30-a-gel/p/4936365380_multi', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 99: {'link': 'No link'}
# Scraped product 100: {'link': 'No link'}
# Scraped product 101: {'link': 'No link'}
# Scraped product 102: {'link': 'No link'}
# Scraped product 103: {'link': 'No link'}
# Scraped product 104: {'link': 'No link'}
# Scraped product 105: {'link': 'No link'}
# Scraped product 106: {'link': 'No link'}
# Scraped product 107: {'link': 'No link'}
# Scraped product 108: {'link': 'No link'}
# Scraped product 109: {'link': 'No link'}
# Scraped product 110: {'link': 'No link'}
# Scraped product 111: {'link': 'No link'}
# Scraped product 112: {'link': 'No link'}
# Scraped product 113: {'link': 'No link'}
# Scraped product 114: {'link': 'No link'}
# Scraped product 115: {'link': 'No link'}
# Scraped product 116: {'link': 'No link'}
# Scraped product 117: {'link': 'No link'}
# Scraped product 118: {'link': 'No link'}
# Scraped product 119: {'link': 'No link'}
# Scraped product 120: {'link': 'No link'}
# Scraped product 121: {'link': 'No link'}
# Scraped product 122: {'link': 'No link'}
# Scraped product 123: {'link': 'No link'}
# Scraped product 124: {'link': 'No link'}
# Scraped product 125: {'link': 'No link'}
# Scraped product 126: {'link': 'No link'}
# Scraped product 127: {'link': 'No link'}
# Scraped product 128: {'link': 'No link'}
# Scraped product 129: {'link': 'No link'}
# Scraped product 130: {'link': 'No link'}
# Scraped product 131: {'link': 'No link'}
# Scraped product 132: {'link': 'No link'}
# Scraped product 133: {'link': 'No link'}
# Scraped product 134: {'link': 'No link'}
# Scraped product 135: {'link': 'No link'}
# Scraped product 136: {'link': 'No link'}
# Scraped product 137: {'link': 'No link'}
# Scraped product 138: {'link': 'No link'}
# Scraped product 139: {'link': 'No link'}
# Scraped product 140: {'link': 'No link'}
# Scraped product 141: {'link': 'No link'}
# Scraped product 142: {'link': 'No link'}
# Scraped product 143: {'link': 'No link'}
# Scraped product 144: {'link': 'No link'}
# Scraped product 145: {'link': 'No link'}
# Scraped product 146: {'link': 'No link'}
# Scraped product 147: {'link': 'No link'}
# Scraped product 148: {'link': 'No link'}
# Scraped product 149: {'link': 'No link'}
# Scraped product 150: {'link': 'No link'}
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[2], line 113
#     110     break
#     112 # Scroll down to load more products
# --> 113 driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#     115 # Wait for the page to load new products
#     116 time.sleep(scroll_pause_time)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:414, in WebDriver.execute_script(self, script, *args)
#     411 converted_args = list(args)
#     412 command = Command.W3C_EXECUTE_SCRIPT
# --> 414 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=128.0.6613.120)
# Stacktrace:
# 	GetHandleVerifier [0x00D98213+26163]
# 	(No symbol) [0x00D29CC4]
# 	(No symbol) [0x00C224C3]
# 	(No symbol) [0x00C0D118]
# 	(No symbol) [0x00C0D039]
# 	(No symbol) [0x00C24960]
# 	(No symbol) [0x00CA3FB9]
# 	(No symbol) [0x00C8AA56]
# 	(No symbol) [0x00C5BE89]
# 	(No symbol) [0x00C5C8CD]
# 	GetHandleVerifier [0x0106D313+2996019]
# 	GetHandleVerifier [0x010C1B89+3342249]
# 	GetHandleVerifier [0x00E27AEF+614159]
# 	GetHandleVerifier [0x00E2F17C+644508]
# 	(No symbol) [0x00D327FD]
# 	(No symbol) [0x00D2F6F8]
# 	(No symbol) [0x00D2F895]
# 	(No symbol) [0x00D21C16]
# 	BaseThreadInitThunk [0x76167BA9+25]
# 	RtlInitializeExceptionChain [0x777BC11B+107]
# 	RtlClearBits [0x777BC09F+191]
