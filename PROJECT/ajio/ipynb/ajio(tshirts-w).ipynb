# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from selenium.common.exceptions import WebDriverException

# Set up the WebDriver with headless option
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Uncomment for headless mode
options.add_argument('--no-sandbox')  # Recommended option for headless mode
options.add_argument('--disable-dev-shm-usage')  # Disable shared memory usage for better stability
options.add_argument('--remote-debugging-port=9222')  # Prevents Chrome from disconnecting DevTools

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Start with the first page
base_url = 'https://www.ajio.com/search/?text=women%20t%20shirst'
driver.get(base_url)

# Initialize an empty list to store product data
product_data = []
max_products = 200  # Set limit to stop after collecting a certain number of products

def extract_product_details():
    products = driver.find_elements(By.CSS_SELECTOR, 'div.item.rilrtl-products-list__item')

    for product in products:
        if len(product_data) >= max_products:  # Stop if we have enough data
            return False

        product_info = {}

        try:
            # Extract product link (using correct CSS selector)
            link_elements = product.find_elements(By.CSS_SELECTOR, 'a')
            product_link = link_elements[0].get_attribute('href') if link_elements else 'No link'
            product_info['link'] = product_link
        except Exception:
            product_info['link'] = 'No link'

        # Now go to the individual product page to extract details
        if product_info['link'] != 'No link':
            try:
                # Open product link in a new tab
                driver.execute_script(f"window.open('{product_info['link']}', '_blank');")
                driver.switch_to.window(driver.window_handles[1])

                # Wait for the product page to load
                time.sleep(3)

                # Extract title
                try:
                    title_elements = driver.find_elements(By.CSS_SELECTOR, 'h2.brand-name')
                    product_info['title'] = title_elements[0].text if title_elements else 'No title'
                except Exception:
                    product_info['title'] = 'No title'

                # Extract price
                try:
                    price_elements = driver.find_elements(By.CSS_SELECTOR, 'div.prod-sp')
                    product_info['price'] = price_elements[0].text if price_elements else 'No price'
                except Exception:
                    product_info['price'] = 'No price'

                # Extract ratings
                try:
                    rating_elements = driver.find_elements(By.CSS_SELECTOR, 'span._3c5q0')
                    product_info['rating'] = rating_elements[0].text if rating_elements else 'No rating'
                except Exception:
                    product_info['rating'] = 'No rating'

                # Extract number of reviews
                try:
                    reviews_elements = driver.find_elements(By.CSS_SELECTOR, 'span._38RNg')
                    product_info['reviews'] = reviews_elements[0].text if reviews_elements else 'No reviews'
                except Exception:
                    product_info['reviews'] = 'No reviews'

                print(f"Scraped details from product page: {product_info}")

                # Close the product tab and switch back to the search results tab
                driver.close()
                driver.switch_to.window(driver.window_handles[0])

                # Wait for the page to return to the main search
                time.sleep(3)

            except Exception as e:
                print(f"Error while scraping product page: {e}")
                product_info['title'] = 'No title'
                product_info['price'] = 'No price'
                product_info['rating'] = 'No rating'
                product_info['reviews'] = 'No reviews'

        # Append the product info to the list
        product_data.append(product_info)

        # Print product information to show the scraping progress
        print(f"Scraped product {len(product_data)}: {product_info}")

    return True  # Continue scraping


# Scroll the page and extract products until we reach the max product limit
scroll_pause_time = 4  # Increased pause time for smoother scrolling

while len(product_data) < max_products:
    try:
        extract_success = extract_product_details()

        if not extract_success:
            break

        # Scroll down to load more products
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for the page to load new products
        time.sleep(scroll_pause_time)

    except WebDriverException as e:
        print(f"WebDriverException occurred: {e}")
        # Optionally: exit loop or handle the exception
        break

# Close the driver after scraping
driver.quit()

# Convert the product data into a DataFrame and save it to an Excel file
df = pd.DataFrame(product_data)
df.to_excel('ajio_w-tshirts.xlsx', index=False)  # Use .to_excel() for Excel format
print('Data saved to ajio_w-tshirts.xlsx.')
# Out:
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-printed-cotton-boxy-fit-round-neck-t-shirt/p/443048353_jetblack', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '3.8', 'reviews': '362 Ratings'}
# Scraped product 1: {'link': 'https://www.ajio.com/dnmx-women-printed-cotton-boxy-fit-round-neck-t-shirt/p/443048353_jetblack', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '3.8', 'reviews': '362 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_black', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 2: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_black', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/teamspirit-typographic-print-crew-neck-t-shirt/p/441135195_navy', 'title': 'TEAMSPIRIT', 'price': '₹139', 'rating': '3.8', 'reviews': '2.3K Ratings'}
# Scraped product 3: {'link': 'https://www.ajio.com/teamspirit-typographic-print-crew-neck-t-shirt/p/441135195_navy', 'title': 'TEAMSPIRIT', 'price': '₹139', 'rating': '3.8', 'reviews': '2.3K Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/styli-crew-neck-t-shirt-with-short-sleeves/p/466578514_beige', 'title': 'STYLI', 'price': '₹584', 'rating': '3.7', 'reviews': '124 Ratings'}
# Scraped product 4: {'link': 'https://www.ajio.com/styli-crew-neck-t-shirt-with-short-sleeves/p/466578514_beige', 'title': 'STYLI', 'price': '₹584', 'rating': '3.7', 'reviews': '124 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-regular-fit-crew-neck-t-shirt/p/443049749_jetblack', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '4.3', 'reviews': '300 Ratings'}
# Scraped product 5: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-regular-fit-crew-neck-t-shirt/p/443049749_jetblack', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '4.3', 'reviews': '300 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/miss-selfridge-women-pack-of-2-selfridge-short-sleeve-bodysuits/p/469648123_greymarlwhite', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹2,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 6: {'link': 'https://www.ajio.com/miss-selfridge-women-pack-of-2-selfridge-short-sleeve-bodysuits/p/469648123_greymarlwhite', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹2,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-cotton-crew-neck-t-shirt/p/443041128_ltbeige', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped product 7: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-cotton-crew-neck-t-shirt/p/443041128_ltbeige', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/globus-drop-shoulder-graphic-printed-oversized-trendy-crop-t-shirt/p/466435247_green', 'title': 'GLOBUS', 'price': '₹859', 'rating': '3.9', 'reviews': '256 Ratings'}
# Scraped product 8: {'link': 'https://www.ajio.com/globus-drop-shoulder-graphic-printed-oversized-trendy-crop-t-shirt/p/466435247_green', 'title': 'GLOBUS', 'price': '₹859', 'rating': '3.9', 'reviews': '256 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/hellcat-women-graphic-print-oversized-crew-neck-t-shirt/p/467267930_beige', 'title': 'HELLCAT', 'price': '₹315', 'rating': '3.2', 'reviews': '504 Ratings'}
# Scraped product 9: {'link': 'https://www.ajio.com/hellcat-women-graphic-print-oversized-crew-neck-t-shirt/p/467267930_beige', 'title': 'HELLCAT', 'price': '₹315', 'rating': '3.2', 'reviews': '504 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/s/min-65-percent-off-5513-42702?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 10: {'link': 'https://www.ajio.com/s/min-65-percent-off-5513-42702?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/teamspirit-typographic-print-crew-neck-t-shirt/p/441135195_offwhite', 'title': 'TEAMSPIRIT', 'price': '₹139', 'rating': '3.8', 'reviews': '2.3K Ratings'}
# Scraped product 11: {'link': 'https://www.ajio.com/teamspirit-typographic-print-crew-neck-t-shirt/p/441135195_offwhite', 'title': 'TEAMSPIRIT', 'price': '₹139', 'rating': '3.8', 'reviews': '2.3K Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-boxy-fit-crew-neck-t-shirt/p/443041129_jetblack', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '217 Ratings'}
# Scraped product 12: {'link': 'https://www.ajio.com/rio-basic-women-boxy-fit-crew-neck-t-shirt/p/443041129_jetblack', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '217 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/miss-selfridge-womenpack-of-2-cropped-t-shirts/p/469651887_whitesage', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹2,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 13: {'link': 'https://www.ajio.com/miss-selfridge-womenpack-of-2-cropped-t-shirts/p/469651887_whitesage', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹2,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/gap-logo-print-slub-t-shirt-with-short-sleeves/p/442602095_black', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': '3.7', 'reviews': '14 Ratings'}
# Scraped product 14: {'link': 'https://www.ajio.com/gap-logo-print-slub-t-shirt-with-short-sleeves/p/442602095_black', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': '3.7', 'reviews': '14 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-basic-daisy-regular-fit-t-shirt/p/443041129_ltbeige', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '217 Ratings'}
# Scraped product 15: {'link': 'https://www.ajio.com/rio-basic-women-basic-daisy-regular-fit-t-shirt/p/443041129_ltbeige', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '217 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/clafoutis-women-typographic-print-loose-fit-v-neck-t-shirt/p/700242457_white', 'title': 'CLAFOUTIS', 'price': '₹285', 'rating': '2.8', 'reviews': '20 Ratings'}
# Scraped product 16: {'link': 'https://www.ajio.com/clafoutis-women-typographic-print-loose-fit-v-neck-t-shirt/p/700242457_white', 'title': 'CLAFOUTIS', 'price': '₹285', 'rating': '2.8', 'reviews': '20 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/force-colour-block-polo-full-length-sleeves-t-shirt/p/464860268_multi', 'title': 'FORCE', 'price': '₹590', 'rating': '3', 'reviews': '1.5K Ratings'}
# Scraped product 17: {'link': 'https://www.ajio.com/force-colour-block-polo-full-length-sleeves-t-shirt/p/464860268_multi', 'title': 'FORCE', 'price': '₹590', 'rating': '3', 'reviews': '1.5K Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-printed-regular-fit-crew-neck-t-shirt/p/443044326_pink', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 18: {'link': 'https://www.ajio.com/dnmx-women-printed-regular-fit-crew-neck-t-shirt/p/443044326_pink', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/difference-of-opinion-graphic-print-crew-neck-t-shirt/p/466489932_blue', 'title': 'DIFFERENCE OF OPINION', 'price': '₹464', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped product 19: {'link': 'https://www.ajio.com/difference-of-opinion-graphic-print-crew-neck-t-shirt/p/466489932_blue', 'title': 'DIFFERENCE OF OPINION', 'price': '₹464', 'rating': '4.3', 'reviews': '3 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/s/alaya-x-max-urb-n-5524-73611?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 20: {'link': 'https://www.ajio.com/s/alaya-x-max-urb-n-5524-73611?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_jetblack', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped product 21: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_jetblack', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dillinger-typographic-print-crew-neck-oversized-t-shirt/p/464228699_red', 'title': 'DILLINGER', 'price': '₹481', 'rating': '3.8', 'reviews': '1.1K Ratings'}
# Scraped product 22: {'link': 'https://www.ajio.com/dillinger-typographic-print-crew-neck-oversized-t-shirt/p/464228699_red', 'title': 'DILLINGER', 'price': '₹481', 'rating': '3.8', 'reviews': '1.1K Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-printed-regular-fit-round-neck-t-shirt/p/443037336_pink', 'title': 'DNMX', 'price': '₹179', 'rating': '3.7', 'reviews': '58 Ratings'}
# Scraped product 23: {'link': 'https://www.ajio.com/dnmx-women-printed-regular-fit-round-neck-t-shirt/p/443037336_pink', 'title': 'DNMX', 'price': '₹179', 'rating': '3.7', 'reviews': '58 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/gap-logo-print-slub-t-shirt-with-short-sleeves/p/442602095_beige', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': '3.7', 'reviews': '14 Ratings'}
# Scraped product 24: {'link': 'https://www.ajio.com/gap-logo-print-slub-t-shirt-with-short-sleeves/p/442602095_beige', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': '3.7', 'reviews': '14 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/color-capital-women-relaxed-fit-v-neck-t-shirt/p/467195332_black', 'title': 'COLOR CAPITAL', 'price': '₹392', 'rating': '4.2', 'reviews': '760 Ratings'}
# Scraped product 25: {'link': 'https://www.ajio.com/color-capital-women-relaxed-fit-v-neck-t-shirt/p/467195332_black', 'title': 'COLOR CAPITAL', 'price': '₹392', 'rating': '4.2', 'reviews': '760 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/superdry-vintage-cl-brand-print-round-neck-t-shirt/p/410338872_02a', 'title': 'SUPERDRY', 'price': '₹1,500', 'rating': '3.7', 'reviews': '59 Ratings'}
# Scraped product 26: {'link': 'https://www.ajio.com/superdry-vintage-cl-brand-print-round-neck-t-shirt/p/410338872_02a', 'title': 'SUPERDRY', 'price': '₹1,500', 'rating': '3.7', 'reviews': '59 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_white', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped product 27: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_white', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/max-striped-crew-neck-t-shirt/p/465940350_black', 'title': 'MAX', 'price': 'MRP₹399', 'rating': '3.4', 'reviews': '413 Ratings'}
# Scraped product 28: {'link': 'https://www.ajio.com/max-striped-crew-neck-t-shirt/p/465940350_black', 'title': 'MAX', 'price': 'MRP₹399', 'rating': '3.4', 'reviews': '413 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_olive', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped product 29: {'link': 'https://www.ajio.com/rio-basic-women-regular-fit-crew-neck-t-shirt/p/443041128_olive', 'title': 'RIO BASIC', 'price': 'MRP₹199', 'rating': '4', 'reviews': '565 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/b/miss-selfridge?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 30: {'link': 'https://www.ajio.com/b/miss-selfridge?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-printed-boxy-fit-round-neck-t-shirt/p/443048348_skyblue', 'title': 'DNMX', 'price': 'MRP₹299', 'rating': '3.7', 'reviews': '42 Ratings'}
# Scraped product 31: {'link': 'https://www.ajio.com/dnmx-women-printed-boxy-fit-round-neck-t-shirt/p/443048348_skyblue', 'title': 'DNMX', 'price': 'MRP₹299', 'rating': '3.7', 'reviews': '42 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/max-women-typographic-print-regular-fit-t-shirt/p/700283369_maroon', 'title': 'MAX', 'price': 'MRP₹249', 'rating': '4.1', 'reviews': '45 Ratings'}
# Scraped product 32: {'link': 'https://www.ajio.com/max-women-typographic-print-regular-fit-t-shirt/p/700283369_maroon', 'title': 'MAX', 'price': 'MRP₹249', 'rating': '4.1', 'reviews': '45 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lagashi-women-regular-fit-round-neck-t-shirt/p/700155624_green', 'title': 'LAGASHI', 'price': '₹506', 'rating': '2', 'reviews': '4 Ratings'}
# Scraped product 33: {'link': 'https://www.ajio.com/lagashi-women-regular-fit-round-neck-t-shirt/p/700155624_green', 'title': 'LAGASHI', 'price': '₹506', 'rating': '2', 'reviews': '4 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/teamspirit-women-striped-relaxed-fit-crew-neck-t-shirt/p/443034796_offwhite', 'title': 'TEAMSPIRIT', 'price': '₹179', 'rating': '3.9', 'reviews': '77 Ratings'}
# Scraped product 34: {'link': 'https://www.ajio.com/teamspirit-women-striped-relaxed-fit-crew-neck-t-shirt/p/443034796_offwhite', 'title': 'TEAMSPIRIT', 'price': '₹179', 'rating': '3.9', 'reviews': '77 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/teamspirit-women-striped-relaxed-fit-crew-neck-t-shirt/p/443034798_green', 'title': 'TEAMSPIRIT', 'price': '₹179', 'rating': '4.2', 'reviews': '97 Ratings'}
# Scraped product 35: {'link': 'https://www.ajio.com/teamspirit-women-striped-relaxed-fit-crew-neck-t-shirt/p/443034798_green', 'title': 'TEAMSPIRIT', 'price': '₹179', 'rating': '4.2', 'reviews': '97 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-graphic-print-oversized-fit-crew-neck-t-shirt/p/443048355_brown', 'title': 'DNMX', 'price': 'MRP₹399', 'rating': '3.9', 'reviews': '40 Ratings'}
# Scraped product 36: {'link': 'https://www.ajio.com/dnmx-women-graphic-print-oversized-fit-crew-neck-t-shirt/p/443048355_brown', 'title': 'DNMX', 'price': 'MRP₹399', 'rating': '3.9', 'reviews': '40 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-relaxed-fit-round-neck-t-shirt/p/443029599_blue', 'title': 'DNMX', 'price': '₹179', 'rating': '4.2', 'reviews': '105 Ratings'}
# Scraped product 37: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-relaxed-fit-round-neck-t-shirt/p/443029599_blue', 'title': 'DNMX', 'price': '₹179', 'rating': '4.2', 'reviews': '105 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-regular-fit-crew-neck-t-shirt/p/443049240_purple', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '4.2', 'reviews': '208 Ratings'}
# Scraped product 38: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-regular-fit-crew-neck-t-shirt/p/443049240_purple', 'title': 'DNMX', 'price': 'MRP₹199', 'rating': '4.2', 'reviews': '208 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/lyra-women-regular-fit-round-neck-t-shirt/p/700237200_red', 'title': 'LYRA', 'price': '₹310', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 39: {'link': 'https://www.ajio.com/lyra-women-regular-fit-round-neck-t-shirt/p/700237200_red', 'title': 'LYRA', 'price': '₹310', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/s/upto-50-percent-off-5534-46251?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 40: {'link': 'https://www.ajio.com/s/upto-50-percent-off-5534-46251?ref=banner', 'title': 'No title', 'price': 'No price', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/kotty-floral-print-loose-fit-crew-neck-t-shirt/p/466551321_yellow', 'title': 'KOTTY', 'price': '₹240', 'rating': '4', 'reviews': '125 Ratings'}
# Scraped product 41: {'link': 'https://www.ajio.com/kotty-floral-print-loose-fit-crew-neck-t-shirt/p/466551321_yellow', 'title': 'KOTTY', 'price': '₹240', 'rating': '4', 'reviews': '125 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_grey', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 42: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_grey', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/max-crew-neck-t-shirt-with-short-sleeves/p/466504485_white', 'title': 'MAX', 'price': 'MRP₹199', 'rating': '3.8', 'reviews': '1.2K Ratings'}
# Scraped product 43: {'link': 'https://www.ajio.com/max-crew-neck-t-shirt-with-short-sleeves/p/466504485_white', 'title': 'MAX', 'price': 'MRP₹199', 'rating': '3.8', 'reviews': '1.2K Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/max-women-striped-regular-fit-crew-neck-t-shirt/p/466823942_pink', 'title': 'MAX', 'price': 'MRP₹399', 'rating': '3.6', 'reviews': '88 Ratings'}
# Scraped product 44: {'link': 'https://www.ajio.com/max-women-striped-regular-fit-crew-neck-t-shirt/p/466823942_pink', 'title': 'MAX', 'price': 'MRP₹399', 'rating': '3.6', 'reviews': '88 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/heylay-women-printed-loose-fit-round-neck-t-shirt/p/467006125_red', 'title': 'HEYLAY', 'price': '₹380', 'rating': '4.2', 'reviews': '664 Ratings'}
# Scraped product 45: {'link': 'https://www.ajio.com/heylay-women-printed-loose-fit-round-neck-t-shirt/p/467006125_red', 'title': 'HEYLAY', 'price': '₹380', 'rating': '4.2', 'reviews': '664 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/miss-selfridge-women-miss-selfridge-pointelle-short-sleeve-t-shirt-with-lace-trim-detail/p/469634915_greymarl', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹1,699', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 46: {'link': 'https://www.ajio.com/miss-selfridge-women-miss-selfridge-pointelle-short-sleeve-t-shirt-with-lace-trim-detail/p/469634915_greymarl', 'title': 'MISS SELFRIDGE', 'price': 'MRP₹1,699', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped details from product page: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-boxy-fit-crew-neck-t-shirt/p/443044341_charcoal', 'title': 'DNMX', 'price': 'MRP₹299', 'rating': '4.3', 'reviews': '139 Ratings'}
# Scraped product 47: {'link': 'https://www.ajio.com/dnmx-women-typographic-print-boxy-fit-crew-neck-t-shirt/p/443044341_charcoal', 'title': 'DNMX', 'price': 'MRP₹299', 'rating': '4.3', 'reviews': '139 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/clafoutis-women-typographic-print-loose-fit-crew-neck-t-shirt/p/700185891_brown', 'title': 'CLAFOUTIS', 'price': '₹375', 'rating': '2.7', 'reviews': '194 Ratings'}
# Scraped product 48: {'link': 'https://www.ajio.com/clafoutis-women-typographic-print-loose-fit-crew-neck-t-shirt/p/700185891_brown', 'title': 'CLAFOUTIS', 'price': '₹375', 'rating': '2.7', 'reviews': '194 Ratings'}
# Scraped details from product page: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_red', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 49: {'link': 'https://www.ajio.com/gap-logo-print-t-shirt-with-raglan-sleeves/p/442588626_red', 'title': 'GAP', 'price': 'MRP₹1,499', 'rating': 'No rating', 'reviews': 'No reviews'}
# Scraped product 50: {'link': 'No link'}
# Scraped product 51: {'link': 'No link'}
# Scraped product 52: {'link': 'No link'}
# Scraped product 53: {'link': 'No link'}
# Scraped product 54: {'link': 'No link'}
# Scraped product 55: {'link': 'No link'}
# Scraped product 56: {'link': 'No link'}
# Scraped product 57: {'link': 'No link'}
# Scraped product 58: {'link': 'No link'}
# Scraped product 59: {'link': 'No link'}
# Scraped product 60: {'link': 'No link'}
# Scraped product 61: {'link': 'No link'}
# Scraped product 62: {'link': 'No link'}
# Scraped product 63: {'link': 'No link'}
# Scraped product 64: {'link': 'No link'}
# Scraped product 65: {'link': 'No link'}
# Scraped product 66: {'link': 'No link'}
# Scraped product 67: {'link': 'No link'}
# Scraped product 68: {'link': 'No link'}
# Scraped product 69: {'link': 'No link'}
# Scraped product 70: {'link': 'No link'}
# Scraped product 71: {'link': 'No link'}
# Scraped product 72: {'link': 'No link'}
# Scraped product 73: {'link': 'No link'}
# Scraped product 74: {'link': 'No link'}
# Scraped product 75: {'link': 'No link'}
# Scraped product 76: {'link': 'No link'}
# Scraped product 77: {'link': 'No link'}
# Scraped product 78: {'link': 'No link'}
# Scraped product 79: {'link': 'No link'}
# Scraped product 80: {'link': 'No link'}
# Scraped product 81: {'link': 'No link'}
# Scraped product 82: {'link': 'No link'}
# Scraped product 83: {'link': 'No link'}
# Scraped product 84: {'link': 'No link'}
# Scraped product 85: {'link': 'No link'}
# Scraped product 86: {'link': 'No link'}
# Scraped product 87: {'link': 'No link'}
# Scraped product 88: {'link': 'No link'}
# Scraped product 89: {'link': 'No link'}
# Scraped product 90: {'link': 'No link'}
# Scraped product 91: {'link': 'No link'}
# Scraped product 92: {'link': 'No link'}
# Scraped product 93: {'link': 'No link'}
# Scraped product 94: {'link': 'No link'}
# Scraped product 95: {'link': 'No link'}
# Scraped product 96: {'link': 'No link'}
# Scraped product 97: {'link': 'No link'}
# Scraped product 98: {'link': 'No link'}
# Scraped product 99: {'link': 'No link'}
# Scraped product 100: {'link': 'No link'}
# Scraped product 101: {'link': 'No link'}
# Scraped product 102: {'link': 'No link'}
# Scraped product 103: {'link': 'No link'}
# Scraped product 104: {'link': 'No link'}
# Scraped product 105: {'link': 'No link'}
# Scraped product 106: {'link': 'No link'}
# Scraped product 107: {'link': 'No link'}
# Scraped product 108: {'link': 'No link'}
# Scraped product 109: {'link': 'No link'}
# Scraped product 110: {'link': 'No link'}
# Scraped product 111: {'link': 'No link'}
# Scraped product 112: {'link': 'No link'}
# Scraped product 113: {'link': 'No link'}
# Scraped product 114: {'link': 'No link'}
# Scraped product 115: {'link': 'No link'}
# Scraped product 116: {'link': 'No link'}
# Scraped product 117: {'link': 'No link'}
# Scraped product 118: {'link': 'No link'}
# Scraped product 119: {'link': 'No link'}
# Scraped product 120: {'link': 'No link'}
# Scraped product 121: {'link': 'No link'}
# Scraped product 122: {'link': 'No link'}
# Scraped product 123: {'link': 'No link'}
# Scraped product 124: {'link': 'No link'}
# Scraped product 125: {'link': 'No link'}
# Scraped product 126: {'link': 'No link'}
# Scraped product 127: {'link': 'No link'}
# Scraped product 128: {'link': 'No link'}
# Scraped product 129: {'link': 'No link'}
# Scraped product 130: {'link': 'No link'}
# Scraped product 131: {'link': 'No link'}
# Scraped product 132: {'link': 'No link'}
# Scraped product 133: {'link': 'No link'}
# Scraped product 134: {'link': 'No link'}
# Scraped product 135: {'link': 'No link'}
# Scraped product 136: {'link': 'No link'}
# Scraped product 137: {'link': 'No link'}
# Scraped product 138: {'link': 'No link'}
# Scraped product 139: {'link': 'No link'}
# Scraped product 140: {'link': 'No link'}
# Scraped product 141: {'link': 'No link'}
# Scraped product 142: {'link': 'No link'}
# Scraped product 143: {'link': 'No link'}
# Scraped product 144: {'link': 'No link'}
# Scraped product 145: {'link': 'No link'}
# Scraped product 146: {'link': 'No link'}
# Scraped product 147: {'link': 'No link'}
# Scraped product 148: {'link': 'No link'}
# Scraped product 149: {'link': 'No link'}
# Scraped product 150: {'link': 'No link'}
# Scraped product 151: {'link': 'No link'}
# Scraped product 152: {'link': 'No link'}
# Scraped product 153: {'link': 'No link'}
# Scraped product 154: {'link': 'No link'}
# Scraped product 155: {'link': 'No link'}
# Scraped product 156: {'link': 'No link'}
# Scraped product 157: {'link': 'No link'}
# Scraped product 158: {'link': 'No link'}
# Scraped product 159: {'link': 'No link'}
# Scraped product 160: {'link': 'No link'}
# Scraped product 161: {'link': 'No link'}
# Scraped product 162: {'link': 'No link'}
# Scraped product 163: {'link': 'No link'}
# Scraped product 164: {'link': 'No link'}
# Scraped product 165: {'link': 'No link'}
# Scraped product 166: {'link': 'No link'}
# Scraped product 167: {'link': 'No link'}
# Scraped product 168: {'link': 'No link'}
# Scraped product 169: {'link': 'No link'}
# Scraped product 170: {'link': 'No link'}
# Scraped product 171: {'link': 'No link'}
# Scraped product 172: {'link': 'No link'}
# Scraped product 173: {'link': 'No link'}
# Scraped product 174: {'link': 'No link'}
# Scraped product 175: {'link': 'No link'}
# Scraped product 176: {'link': 'No link'}
# Scraped product 177: {'link': 'No link'}
# Scraped product 178: {'link': 'No link'}
# Scraped product 179: {'link': 'No link'}
# Scraped product 180: {'link': 'No link'}
# Scraped product 181: {'link': 'No link'}
# Scraped product 182: {'link': 'No link'}
# Scraped product 183: {'link': 'No link'}
# Scraped product 184: {'link': 'No link'}
# Scraped product 185: {'link': 'No link'}
# Scraped product 186: {'link': 'No link'}
# Scraped product 187: {'link': 'No link'}
# Scraped product 188: {'link': 'No link'}
# WebDriverException occurred: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=128.0.6613.120)
# Stacktrace:
# 	GetHandleVerifier [0x00D98213+26163]
# 	(No symbol) [0x00D29CC4]
# 	(No symbol) [0x00C224C3]
# 	(No symbol) [0x00C0D118]
# 	(No symbol) [0x00C0D039]
# 	(No symbol) [0x00C24960]
# 	(No symbol) [0x00CA3FB9]
# 	(No symbol) [0x00C8AA56]
# 	(No symbol) [0x00C5BE89]
# 	(No symbol) [0x00C5C8CD]
# 	GetHandleVerifier [0x0106D313+2996019]
# 	GetHandleVerifier [0x010C1B89+3342249]
# 	GetHandleVerifier [0x00E27AEF+614159]
# 	GetHandleVerifier [0x00E2F17C+644508]
# 	(No symbol) [0x00D327FD]
# 	(No symbol) [0x00D2F6F8]
# 	(No symbol) [0x00D2F895]
# 	(No symbol) [0x00D21C16]
# 	BaseThreadInitThunk [0x76167BA9+25]
# 	RtlInitializeExceptionChain [0x777BC11B+107]
# 	RtlClearBits [0x777BC09F+191]
#
# Data saved to ajio_w-tshirts.xlsx.
